# %%
# Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Loading the data
df = pd.read_csv(r'C:\Users\jugal\OneDrive\Documents\Ironhack_project\Final_project\merged_blood_pressure_demographic_data.csv')
df
# Out:
#            SEQN BPAOARM  BPAOCSZ  BPXOSY1  BPXODI1  BPXOSY2  BPXODI2  BPXOSY3  \
# 0      109264.0       R      3.0    109.0     67.0    109.0     68.0    106.0
# 1      109266.0       R      4.0     99.0     56.0     99.0     55.0     99.0
# 2      109270.0       R      3.0    123.0     73.0    124.0     77.0    127.0
# 3      109271.0       R      4.0    102.0     65.0    108.0     68.0    111.0
# 4      109273.0       R      3.0    116.0     68.0    110.0     66.0    115.0
# ...         ...     ...      ...      ...      ...      ...      ...      ...
# 10347  124815.0       R      4.0    141.0     87.0    138.0     86.0    141.0
# 10348  124817.0       R      4.0    111.0     69.0    112.0     67.0    113.0
# 10349  124818.0       R      4.0    106.0     67.0    108.0     65.0     95.0
# 10350  124821.0       R      3.0    121.0     66.0    122.0     67.0    129.0
# 10351  124822.0       R      3.0    122.0     55.0    121.0     56.0    123.0
#
#        BPXODI3  BMDSTATS  ...  BMXARML  BMXARMC  BMXWAIST  BMXHIP  \
# 0         66.0       1.0  ...     33.8     22.7      63.8    85.0
# 1         52.0       1.0  ...     34.7     35.8     117.9   126.1
# 2         70.0       1.0  ...     36.1     31.0      91.4   103.4
# 3         68.0       1.0  ...     42.0     38.2     120.4   108.2
# 4         68.0       1.0  ...     41.1     30.2      86.8    94.5
# ...        ...       ...  ...      ...      ...       ...     ...
# 10347     87.0       1.0  ...     37.8     35.7      99.3   105.3
# 10348     66.0       1.0  ...     34.8     39.5     110.0   121.4
# 10349     70.0       1.0  ...     38.6     33.6     114.7   118.0
# 10350     67.0       1.0  ...     39.5     31.4      97.1    99.8
# 10351     58.0       1.0  ...     40.3     29.2      86.9    90.5
#
#        Survery_year   Age  Gender  Education           Ethnicity  \
# 0              66.0  13.0  Female    Unknowm    Mexican American
# 1              66.0  29.0  Female        5.0          Other Race
# 2              66.0  11.0  Female    Unknowm  Non-Hispanic Black
# 3              66.0  49.0    Male        2.0  Non-Hispanic White
# 4              66.0  36.0    Male        4.0  Non-Hispanic White
# ...             ...   ...     ...        ...                 ...
# 10347          66.0  52.0    Male        4.0  Non-Hispanic Black
# 10348          66.0  67.0  Female        2.0    Mexican American
# 10349          66.0  40.0    Male        5.0  Non-Hispanic Black
# 10350          66.0  63.0    Male        2.0  Non-Hispanic Black
# 10351          66.0  74.0    Male        3.0      Other Hispanic
#
#        incom_to_pov_ratio
# 0                    0.83
# 1                    5.00
# 2                    1.88
# 3                    1.96
# 4                    0.83
# ...                   ...
# 10347                5.00
# 10348                2.19
# 10349                3.82
# 10350                3.71
# 10351                1.96
#
# [10352 rows x 25 columns]

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10352 entries, 0 to 10351
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SEQN                10352 non-null  float64
#  1   BPAOARM             9471 non-null   object
#  2   BPAOCSZ             10352 non-null  float64
#  3   BPXOSY1             10352 non-null  float64
#  4   BPXODI1             10352 non-null  float64
#  5   BPXOSY2             10352 non-null  float64
#  6   BPXODI2             10352 non-null  float64
#  7   BPXOSY3             10352 non-null  float64
#  8   BPXODI3             10352 non-null  float64
#  9   BMDSTATS            10352 non-null  float64
#  10  BMXWT               10352 non-null  float64
#  11  BMXHT               10352 non-null  float64
#  12  BMXBMI              10352 non-null  float64
#  13  BMDBMIC             10352 non-null  float64
#  14  BMXLEG              10352 non-null  float64
#  15  BMXARML             10352 non-null  float64
#  16  BMXARMC             10352 non-null  float64
#  17  BMXWAIST            10352 non-null  float64
#  18  BMXHIP              10352 non-null  float64
#  19  Survery_year        10352 non-null  float64
#  20  Age                 10352 non-null  float64
#  21  Gender              10352 non-null  object
#  22  Education           10352 non-null  object
#  23  Ethnicity           10352 non-null  object
#  24  incom_to_pov_ratio  10352 non-null  float64
# dtypes: float64(21), object(4)
# memory usage: 2.0+ MB
# SEQN                    0
# BPAOARM               881
# BPAOCSZ                 0
# BPXOSY1                 0
# BPXODI1                 0
# BPXOSY2                 0
# BPXODI2                 0
# BPXOSY3                 0
# BPXODI3                 0
# BMDSTATS                0
# BMXWT                   0
# BMXHT                   0
# BMXBMI                  0
# BMDBMIC                 0
# BMXLEG                  0
# BMXARML                 0
# BMXARMC                 0
# BMXWAIST                0
# BMXHIP                  0
# Survery_year            0
# Age                     0
# Gender                  0
# Education               0
# Ethnicity               0
# incom_to_pov_ratio      0
# dtype: int64

# %%
df.dtypes
# Out:
# SEQN                  float64
# BPAOARM                object
# BPAOCSZ               float64
# BPXOSY1               float64
# BPXODI1               float64
# BPXOSY2               float64
# BPXODI2               float64
# BPXOSY3               float64
# BPXODI3               float64
# BMDSTATS              float64
# BMXWT                 float64
# BMXHT                 float64
# BMXBMI                float64
# BMDBMIC               float64
# BMXLEG                float64
# BMXARML               float64
# BMXARMC               float64
# BMXWAIST              float64
# BMXHIP                float64
# Survery_year          float64
# Age                   float64
# Gender                 object
# Education              object
# Ethnicity              object
# incom_to_pov_ratio    float64
# dtype: object

# %% [markdown]
# ### Renming the column name

# %%
new_column_names = {
    'BPAOARM': 'ArmCircumference',
    'BPAOCSZ': 'CuffSize',
    'BPXOSY1': 'SystolicBP1',
    'BPXODI1': 'DiastolicBP1',
    'BPXOSY2': 'SystolicBP2',
    'BPXODI2': 'DiastolicBP2',
    'BPXOSY3': 'SystolicBP3',
    'BPXODI3': 'DiastolicBP3',
    'BMDSTATS': 'BodyMeasurementStatus',
    'BMXWT': 'Weight',
    'BMXHT': 'Height',
    'BMXBMI': 'BMI',
    'BMDBMIC': 'BMICategory',
    'BMXLEG': 'LegLength',
    'BMXARML': 'ArmLength',
    'BMXARMC': 'ArmCircumference',
    'BMXWAIST': 'WaistCircumference',
    'BMXHIP': 'HipCircumference'
}

df = df.rename(columns=new_column_names)

# %%
df['ArmCircumference'] = df['ArmCircumference'].apply(pd.to_numeric, errors='coerce') # Converts to number, sets invalid to NaN

# Prepare the mapping dictionaries
gender_map = {'Male': 1, 'Female': 0}
ethnicity_map = {
    'Mexican American': 1, 
    'Other Hispanic': 2,
    'Non-Hispanic White': 3, 
    'Non-Hispanic Black': 4, 
    'Other Race': 5
}

# Applying the transformation
df = df.assign(
    Gender = df['Gender'].map(gender_map),
    Ethnicity = df['Ethnicity'].map(ethnicity_map)
)

# %%
# Drop columns with more than 30% missing values
df = df.dropna(thresh=len(df) * 0.7, axis=1)
df
# Out:
#            SEQN  CuffSize  SystolicBP1  DiastolicBP1  SystolicBP2  \
# 0      109264.0       3.0        109.0          67.0        109.0
# 1      109266.0       4.0         99.0          56.0         99.0
# 2      109270.0       3.0        123.0          73.0        124.0
# 3      109271.0       4.0        102.0          65.0        108.0
# 4      109273.0       3.0        116.0          68.0        110.0
# ...         ...       ...          ...           ...          ...
# 10347  124815.0       4.0        141.0          87.0        138.0
# 10348  124817.0       4.0        111.0          69.0        112.0
# 10349  124818.0       4.0        106.0          67.0        108.0
# 10350  124821.0       3.0        121.0          66.0        122.0
# 10351  124822.0       3.0        122.0          55.0        121.0
#
#        DiastolicBP2  SystolicBP3  DiastolicBP3  BodyMeasurementStatus  Weight  \
# 0              68.0        106.0          66.0                    1.0    42.2
# 1              55.0         99.0          52.0                    1.0    97.1
# 2              77.0        127.0          70.0                    1.0    75.3
# 3              68.0        111.0          68.0                    1.0    98.8
# 4              66.0        115.0          68.0                    1.0    74.3
# ...             ...          ...           ...                    ...     ...
# 10347          86.0        141.0          87.0                    1.0    94.3
# 10348          67.0        113.0          66.0                    1.0    82.8
# 10349          65.0         95.0          70.0                    1.0   108.8
# 10350          67.0        129.0          67.0                    1.0    79.5
# 10351          56.0        123.0          58.0                    1.0    59.7
#
#        ...  LegLength  ArmLength  ArmCircumference  WaistCircumference  \
# 0      ...       36.3       33.8              22.7                63.8
# 1      ...       40.8       34.7              35.8               117.9
# 2      ...       42.6       36.1              31.0                91.4
# 3      ...       40.1       42.0              38.2               120.4
# 4      ...       41.0       41.1              30.2                86.8
# ...    ...        ...        ...               ...                 ...
# 10347  ...       44.6       37.8              35.7                99.3
# 10348  ...       32.8       34.8              39.5               110.0
# 10349  ...       45.6       38.6              33.6               114.7
# 10350  ...       42.0       39.5              31.4                97.1
# 10351  ...       41.1       40.3              29.2                86.9
#
#        HipCircumference   Age  Gender  Education  Ethnicity  \
# 0                  85.0  13.0       0    Unknowm          1
# 1                 126.1  29.0       0        5.0          5
# 2                 103.4  11.0       0    Unknowm          4
# 3                 108.2  49.0       1        2.0          3
# 4                  94.5  36.0       1        4.0          3
# ...                 ...   ...     ...        ...        ...
# 10347             105.3  52.0       1        4.0          4
# 10348             121.4  67.0       0        2.0          1
# 10349             118.0  40.0       1        5.0          4
# 10350              99.8  63.0       1        2.0          4
# 10351              90.5  74.0       1        3.0          2
#
#        incom_to_pov_ratio
# 0                    0.83
# 1                    5.00
# 2                    1.88
# 3                    1.96
# 4                    0.83
# ...                   ...
# 10347                5.00
# 10348                2.19
# 10349                3.82
# 10350                3.71
# 10351                1.96
#
# [10352 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# SEQN                     0
# CuffSize                 0
# SystolicBP1              0
# DiastolicBP1             0
# SystolicBP2              0
# DiastolicBP2             0
# SystolicBP3              0
# DiastolicBP3             0
# BodyMeasurementStatus    0
# Weight                   0
# Height                   0
# BMI                      0
# BMICategory              0
# LegLength                0
# ArmLength                0
# ArmCircumference         0
# WaistCircumference       0
# HipCircumference         0
# Age                      0
# Gender                   0
# Education                0
# Ethnicity                0
# incom_to_pov_ratio       0
# dtype: int64

# %% [markdown]
# # Distribution of blood pressure readings
# sns.histplot(df['SystolicBP1'], bins=30, kde=True)  # Systolic BP distribution
# plt.title("Distribution of Systolic Blood Pressure")
# plt.show()

# %% [markdown]
# ### Age & Gender Analysis

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["Gender"], y=df["SystolicBP1"])
plt.xticks(ticks=[0, 1], labels=["Female", "Male"])
plt.title("Systolic Blood Pressure by Gender")
plt.show()

# %%
sns.scatterplot(x=df["Gender"], y=df["SystolicBP1"])  # BP vs. Age
plt.title("Systolic BP vs. Age")
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[245], line 3
#       1 # Correlation Heatmap
#       2 plt.figure(figsize=(12,8))
# ----> 3 sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
#       4 plt.title("Feature Correlation Heatmap")
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Unknowm'

# %% [markdown]
# ### Age & Hypetension Analysis ( Old vs young)

# %%
df.loc[:, "Age"] = pd.cut(df["Gender"], bins=[0, 40, 60, 120], labels=["Young", "Middle-age", "Elderly"])

plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Age'], y=df["SystolicBP1"])
plt.title("Systolic Blood Pressure Across Age Groups")
plt.show()

# Correlation
df[["Gender", "SystolicBP1"]].corr() # Check correlation with BP
# Out:
# C:\Users\jugal\AppData\Local\Temp\ipykernel_26620\4011092039.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[NaN, NaN, NaN, 'Young', 'Young', ..., 'Young', NaN, 'Young', 'Young', 'Young']
# Length: 10352
# Categories (3, object): ['Young' < 'Middle-age' < 'Elderly']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, "Age"] = pd.cut(df["Gender"], bins=[0, 40, 60, 120], labels=["Young", "Middle-age", "Elderly"])
#                Gender  SystolicBP1
# Gender       1.000000     0.121924
# SystolicBP1  0.121924     1.000000

# %% [markdown]
# ### Ethnicity & Blood pressure Analysis

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df["Ethnicity"], y=df["SystolicBP1"])
plt.xticks(rotation=45)
plt.title("Systolic Blood Pressure by Ethnicity")
plt.show()

# %% [markdown]
# ### BMI & Hypertension Relationship

# %%
df.loc[:, 'BMI_Category'] = pd.cut(df["BMICategory"], bins=[0, 18.5, 25, 30, 50], labels=["Underweight", "Normal", "Overweight", "Obese"]) # used .loc for assigement

plt.figure(figsize=(8, 5))
sns.boxplot(x=df["BMI_Category"], y=df["SystolicBP1"])
plt.title("Systolic BP across BMI Categories")
plt.show()

df[["BMICategory", "SystolicBP1"]].corr()  # Checks the correlation with BP
# Out:
#              BMICategory  SystolicBP1
# BMICategory     1.000000    -0.203255
# SystolicBP1    -0.203255     1.000000

# %% [markdown]
# ### Geographic or Socioeconomic Factors

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Education'], y=df['SystolicBP1'])
plt.title('Systolic BP by Education Level')
plt.show()

# %% [markdown]
# ### Distribution Analysis of Blood Pressure Readings

# %% [markdown]
# #### GoalÇ To chech the distribution of sytolic and diastolic BP to identify skewness, ouliers and trends

# %%
plt.figure(figsize=(12, 5))

# Systolic BP Distribution
plt.subplot(1, 2, 1)
sns.histplot(df["SystolicBP1"], bins=30, kde=True, color="blue")
plt.title("Distribution of Systolic Blood Pressure")
# Out:
# Text(0.5, 1.0, 'Distribution of Systolic Blood Pressure')

# %%
# Diastolic BP Distribution
plt.subplot(1, 2, 2)
sns.histplot(df["DiastolicBP1"], bins=30, kde=True, color="red")
plt.title("Distribution of Diastolic Blood Pressure")

plt.show()

# %% [markdown]
# ### Blood Pressure Trends over time
# #### Goal: To identiy in BP leverls over different survey years as it helps to detect lifestyle, dietary, or environmental factors affecting BP over time

# %%
df_grouped = df.groupby("Survery_year")[["SystolicBP1", "DiastolicBP1"]].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.lineplot(x=df_grouped["Survery_year"], y=df_grouped["SystolicBP1"], marker="o", label="Systolic BP")
sns.lineplot(x=df_grouped["Survery_year"], y=df_grouped["DiastolicBP1"], marker="s", label="Diastolic BP")
plt.title("Trend of Blood Pressure Over Years")
plt.legend()
plt.show()

# %% [markdown]
# ### Correlation Heatmap (Feature relationship)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Blood Pressure & Blood Measure')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[319], line 2
#       1 plt.figure(figsize=(10,8))
# ----> 2 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#       3 plt.title('Correlation Heatmap of Blood Pressure & Blood Measure')
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Unknowm'

# %% [markdown]
# ### Outlier Deteection (Boxplots && IQR)
# #### Goal: Detect outliers in BP reading to ensure a clean dataset as it can distort analysis and impact predictive models.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['SystolicBP1'])
plt.title('Boxplot of Systolilc Blood Pressure')
plt.show()

# %% [markdown]
# ### Hypertension Risk Across Socioeconomic status

# %%
df["BP_Category"] = pd.cut(df["SystolicBP1"], bins=[0, 120, 130, 200], labels=["Normal", "Pre-Hypertension", "Hypertensive"])

plt.figure(figsize=(8, 5))
sns.boxplot(x=df["BP_Category"], y=df["incom_to_pov_ratio"])
plt.title("Blood Pressure by Income Level")
plt.show()

# %% [markdown]
# ### Hypertension & Physical Measures (Waist, Weight, Leg Length, etc.)

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['WaistCircumference'], y=df['SystolicBP1'])
plt.title('Systolic Blood Pressure vs. Waist Circumference')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Predictive Modeling Readiness (MULticollinearity - VIF Analysis)
# #### Goal: To identify highly correlated variables that may distort machine learning models

# %%
x = df[['BMI', 'WaistCircumference', 'Height', 'Weight', 'SystolicBP1']]
vif_data = pd.DataFrame()
vif_data['Feature'] = x.columns
vif_data['VIF'] = [variance_inflation_factor(x.values, i) for i in range (x.shape[1])]
vif_data
# Out:
#               Feature         VIF
# 0                 BMI  109.432714
# 1  WaistCircumference  171.437538
# 2              Height   59.757511
# 3              Weight   64.215532
# 4         SystolicBP1   43.464028
